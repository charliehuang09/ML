# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
max_plot = np.load('/Users/charlie/ML/max.npy')
mean_plot = np.load('/Users/charlie/ML/mean.npy')

# %%
print(mean_plot)
# Out:
# [1.11       0.97       1.85       1.26       1.77       2.
#  1.59       2.81       1.01       2.01       3.34343434 1.85858586
#  2.88888889 2.72       2.24       2.88118812 0.9009901  2.33663366
#  2.57425743 3.40594059 2.07       6.76237624 2.13861386 2.13861386]

# %%
plt.plot(mean_plot)
plt.plot(max_plot)
plt.legend(['Mean Plot', 'Max Plot'])

# %%
print(max(max_plot), max(mean_plot))
# Out:
# 1000.0 6.762376237623762

# %%
for i in range(len(mean_plot)):
    mean_plot[i] = np.mean(mean_plot[i:i+500])
for i in range(len(max_plot)):
    max_plot[i] = np.mean(max_plot[i:i+500])

# %%
plt.plot(mean_plot)
plt.plot(max_plot)
plt.legend(['Mean Plot', 'Max Plot'])
