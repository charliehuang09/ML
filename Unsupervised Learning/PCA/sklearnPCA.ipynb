# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import math
import random

# %%
def generateData(slopes, samples, deviation, l, u):
    X = []
    Y = []
    data = []
    for index in range(len(slopes)):
        for i in range(samples):
            x = random.uniform(l, u)
            y = slopes[index] * x + random.uniform(-deviation, deviation)
            X.append(x)
            Y.append(y)
            data.append([x, y])
    return np.array(X), np.array(Y), np.array(data)

# %%
X, Y, data = generateData(np.array([1]), 50, 5, -100, 100)
plt.scatter(X, Y)

# %%
def abline(slope, intercept=0):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')

# %%
pca = PCA(n_components=2)
pca.fit(data)
PCA(n_components=2)
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
pc1 = pca.components_[0][0] / pca.components_[0][1]
pc2 = pca.components_[1][0] / pca.components_[1][1]
plt.scatter(X, Y)
abline(pc1, 0)
abline(pc2, 0)
# Out:
# [9.99200530e-01 7.99470432e-04]
# [531.99634525  15.04816429]

# %%
plt.scatter(X * pca.components_[0][0] + Y * pca.components_[0][1], X * pca.components_[1][0] + Y * pca.components_[1][1])
abline(pc1, 0)
abline(pc2, 0)

# %% [markdown]
# **To Do:**
# Autoscale
